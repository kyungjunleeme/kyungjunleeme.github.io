# %%
import json
import pandas as pd
import numpy as np

'''bbox[0] = 'ymin'
   bbox[1] = 'xmin'
   bbox[2] = 'ymax'
   bbox[3] = 'xmax'
# 0: ymin, 1: xmin, 2: ymax, 3: xmax'''
'''
def class_text_to_int(row_label):
if row_label == 'hand':
return 1
elif row_label == 'grab_bottle_hand':
return 2
elif row_label == 'face':
return 3
elif row_label == 'mouth':
return 4
elif row_label == 'open_mouth':
return 5
elif row_label == 'bottle':
return 6
elif row_label == 'open_bottle':
return 7
elif row_label == 'cap':
return 8
elif row_label == 'pill':
return 9
elif row_label == 'cup':
return 10
else:
None
'''
colum_list = ['json_source', 'filename', 'width', 'height', 'obj_name', 'xmin', 'ymin', 'xmax', 'ymax', 'score', 'obj_idx']

# row_list = []

# per_file_per_object_info_list = []

df = pd.DataFrame(columns=colum_list)


with open('2020_02_26_Test_LHW_01.json') as json_file:
    json_data = json.load(json_file)
    file_name_list = list(json_data)         
    for filename in file_name_list:
        '''파일 1개당 json 정보'''
        '''case_1: json 정보 있는 경우 _ case_2: json 정보 없는 경우'''
        file_json_info = json_data[filename]
        if not file_json_info:
                json_source = '1106_object_list.json'
                obj_name = 'Null'
                obj_idx = 'Null'
                score = 'Null'
                ymin = 'Null'
                xmin = 'Null'
                ymax = 'Null'
                xmax = 'Null'
                width = 'Null'
                height = 'Null'
                df = df.append(pd.DataFrame([['1106_object_list.json', filename+'_', width, height, obj_name, xmin, ymin, xmax, ymax, score, obj_idx]], columns=colum_list), ignore_index=True)
                print(df)
        else:
            '''파일 1개당 감지된_되어야하는_object 갯수'''
            obj_cnt_list = list(file_json_info)
            print(obj_cnt_list)
            '''per_obj_cnt 수정 필요(삭제)'''
            per_obj_cnt = len(obj_cnt_list)
            for i in obj_cnt_list:
                final_info = file_json_info[i]
                print(final_info)
                try:
                    json_source = '1106_object_list.json'
                    obj_name = final_info['name']
                    obj_idx = final_info['obj']
                    score = final_info['score']
                    ymin = final_info['bbox'][0]
                    xmin = final_info['bbox'][1]
                    ymax = final_info['bbox'][2]
                    xmax = final_info['bbox'][3]
                    width = final_info['size'][0]
                    height = final_info['size'][1]
                    df = df.append(pd.DataFrame([['1106_object_list.json', filename+'_', width, height, obj_name, xmin, ymin, xmax, ymax, score, obj_idx]], columns=colum_list), ignore_index=True)
                    print(df)
                except:
                    pass

        
        
        '''(위에서 json 정보 없는 경우에서 걸러짐) case_1: object 있는경우 // case_2: object 없는 경우'''
        
        '''json 내 obj, name, score, bbox, size'''
# Out:
#              json_source                     filename width height obj_name  \
# 0  1106_object_list.json  20IHPA1A_Test_LHW_01_1.jpg_  Null   Null     Null
#
#    xmin  ymin  xmax  ymax score obj_idx
# 0  Null  Null  Null  Null  Null    Null
# ['0']
# {'obj': 8, 'name': 'grab_bottle_body', 'score': 0.952, 'bbox': [9.2448, 434.304, 318.384, 1151.872], 'size': [1280, 720]}
#              json_source                     filename width height  \
# 0  1106_object_list.json  20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1  1106_object_list.json  20IHPA1A_Test_LHW_01_2.jpg_  1280    720
#
#            obj_name     xmin    ymin     xmax     ymax  score obj_idx
# 0              Null     Null    Null     Null     Null   Null    Null
# 1  grab_bottle_body  434.304  9.2448  1151.87  318.384  0.952       8
# ['0']
# {'obj': 8, 'name': 'grab_bottle_body', 'score': 0.8984, 'bbox': [5.09616, 416.76800000000003, 304.488, 1085.312], 'size': [1280, 720]}
#              json_source                     filename width height  \
# 0  1106_object_list.json  20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1  1106_object_list.json  20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2  1106_object_list.json  20IHPA1A_Test_LHW_01_3.jpg_  1280    720
#
#            obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0              Null     Null     Null     Null     Null    Null    Null
# 1  grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2  grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# ['0']
# {'obj': 8, 'name': 'grab_bottle_body', 'score': 0.8468, 'bbox': [10.7208, 420.224, 310.10400000000004, 1064.96], 'size': [1280, 720]}
#              json_source                     filename width height  \
# 0  1106_object_list.json  20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1  1106_object_list.json  20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2  1106_object_list.json  20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3  1106_object_list.json  20IHPA1A_Test_LHW_01_4.jpg_  1280    720
#
#            obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0              Null     Null     Null     Null     Null    Null    Null
# 1  grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2  grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3  grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
#              json_source                     filename width height  \
# 0  1106_object_list.json  20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1  1106_object_list.json  20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2  1106_object_list.json  20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3  1106_object_list.json  20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4  1106_object_list.json  20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
#
#            obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0              Null     Null     Null     Null     Null    Null    Null
# 1  grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2  grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3  grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4              Null     Null     Null     Null     Null    Null    Null
#              json_source                     filename width height  \
# 0  1106_object_list.json  20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1  1106_object_list.json  20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2  1106_object_list.json  20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3  1106_object_list.json  20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4  1106_object_list.json  20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# 5  1106_object_list.json  20IHPA1A_Test_LHW_01_6.jpg_  Null   Null
#
#            obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0              Null     Null     Null     Null     Null    Null    Null
# 1  grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2  grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3  grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4              Null     Null     Null     Null     Null    Null    Null
# 5              Null     Null     Null     Null     Null    Null    Null
#              json_source                     filename width height  \
# 0  1106_object_list.json  20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1  1106_object_list.json  20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2  1106_object_list.json  20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3  1106_object_list.json  20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4  1106_object_list.json  20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# 5  1106_object_list.json  20IHPA1A_Test_LHW_01_6.jpg_  Null   Null
# 6  1106_object_list.json  20IHPA1A_Test_LHW_01_7.jpg_  Null   Null
#
#            obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0              Null     Null     Null     Null     Null    Null    Null
# 1  grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2  grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3  grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4              Null     Null     Null     Null     Null    Null    Null
# 5              Null     Null     Null     Null     Null    Null    Null
# 6              Null     Null     Null     Null     Null    Null    Null
# ['0']
# {'obj': 8, 'name': 'grab_bottle_body', 'score': 0.8019, 'bbox': [19.4904, 400.512, 401.25600000000003, 982.912], 'size': [1280, 720]}
#              json_source                     filename width height  \
# 0  1106_object_list.json  20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1  1106_object_list.json  20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2  1106_object_list.json  20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3  1106_object_list.json  20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4  1106_object_list.json  20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# 5  1106_object_list.json  20IHPA1A_Test_LHW_01_6.jpg_  Null   Null
# 6  1106_object_list.json  20IHPA1A_Test_LHW_01_7.jpg_  Null   Null
# 7  1106_object_list.json  20IHPA1A_Test_LHW_01_8.jpg_  1280    720
#
#            obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0              Null     Null     Null     Null     Null    Null    Null
# 1  grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2  grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3  grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4              Null     Null     Null     Null     Null    Null    Null
# 5              Null     Null     Null     Null     Null    Null    Null
# 6              Null     Null     Null     Null     Null    Null    Null
# 7  grab_bottle_body  400.512  19.4904  982.912  401.256  0.8019       8
#              json_source                     filename width height  \
# 0  1106_object_list.json  20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1  1106_object_list.json  20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2  1106_object_list.json  20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3  1106_object_list.json  20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4  1106_object_list.json  20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# 5  1106_object_list.json  20IHPA1A_Test_LHW_01_6.jpg_  Null   Null
# 6  1106_object_list.json  20IHPA1A_Test_LHW_01_7.jpg_  Null   Null
# 7  1106_object_list.json  20IHPA1A_Test_LHW_01_8.jpg_  1280    720
# 8  1106_object_list.json  20IHPA1A_Test_LHW_01_9.jpg_  Null   Null
#
#            obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0              Null     Null     Null     Null     Null    Null    Null
# 1  grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2  grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3  grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4              Null     Null     Null     Null     Null    Null    Null
# 5              Null     Null     Null     Null     Null    Null    Null
# 6              Null     Null     Null     Null     Null    Null    Null
# 7  grab_bottle_body  400.512  19.4904  982.912  401.256  0.8019       8
# 8              Null     Null     Null     Null     Null    Null    Null
# ['0']
# {'obj': 8, 'name': 'grab_bottle_body', 'score': 0.9973, 'bbox': [23.688, 432.0, 371.23199999999997, 1061.376], 'size': [1280, 720]}
#              json_source                      filename width height  \
# 0  1106_object_list.json   20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1  1106_object_list.json   20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2  1106_object_list.json   20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3  1106_object_list.json   20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4  1106_object_list.json   20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# 5  1106_object_list.json   20IHPA1A_Test_LHW_01_6.jpg_  Null   Null
# 6  1106_object_list.json   20IHPA1A_Test_LHW_01_7.jpg_  Null   Null
# 7  1106_object_list.json   20IHPA1A_Test_LHW_01_8.jpg_  1280    720
# 8  1106_object_list.json   20IHPA1A_Test_LHW_01_9.jpg_  Null   Null
# 9  1106_object_list.json  20IHPA1A_Test_LHW_01_10.jpg_  1280    720
#
#            obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0              Null     Null     Null     Null     Null    Null    Null
# 1  grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2  grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3  grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4              Null     Null     Null     Null     Null    Null    Null
# 5              Null     Null     Null     Null     Null    Null    Null
# 6              Null     Null     Null     Null     Null    Null    Null
# 7  grab_bottle_body  400.512  19.4904  982.912  401.256  0.8019       8
# 8              Null     Null     Null     Null     Null    Null    Null
# 9  grab_bottle_body      432   23.688  1061.38  371.232  0.9973       8
# ['0']
# {'obj': 8, 'name': 'grab_bottle_body', 'score': 0.9995, 'bbox': [27.7056, 422.656, 364.60799999999995, 1044.736], 'size': [1280, 720]}
#               json_source                      filename width height  \
# 0   1106_object_list.json   20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1   1106_object_list.json   20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2   1106_object_list.json   20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3   1106_object_list.json   20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4   1106_object_list.json   20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# 5   1106_object_list.json   20IHPA1A_Test_LHW_01_6.jpg_  Null   Null
# 6   1106_object_list.json   20IHPA1A_Test_LHW_01_7.jpg_  Null   Null
# 7   1106_object_list.json   20IHPA1A_Test_LHW_01_8.jpg_  1280    720
# 8   1106_object_list.json   20IHPA1A_Test_LHW_01_9.jpg_  Null   Null
# 9   1106_object_list.json  20IHPA1A_Test_LHW_01_10.jpg_  1280    720
# 10  1106_object_list.json  20IHPA1A_Test_LHW_01_11.jpg_  1280    720
#
#             obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0               Null     Null     Null     Null     Null    Null    Null
# 1   grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2   grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3   grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4               Null     Null     Null     Null     Null    Null    Null
# 5               Null     Null     Null     Null     Null    Null    Null
# 6               Null     Null     Null     Null     Null    Null    Null
# 7   grab_bottle_body  400.512  19.4904  982.912  401.256  0.8019       8
# 8               Null     Null     Null     Null     Null    Null    Null
# 9   grab_bottle_body      432   23.688  1061.38  371.232  0.9973       8
# 10  grab_bottle_body  422.656  27.7056  1044.74  364.608  0.9995       8
# ['0']
# {'obj': 8, 'name': 'grab_bottle_body', 'score': 0.9928, 'bbox': [15.804, 444.416, 351.0, 1106.688], 'size': [1280, 720]}
#               json_source                      filename width height  \
# 0   1106_object_list.json   20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1   1106_object_list.json   20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2   1106_object_list.json   20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3   1106_object_list.json   20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4   1106_object_list.json   20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# 5   1106_object_list.json   20IHPA1A_Test_LHW_01_6.jpg_  Null   Null
# 6   1106_object_list.json   20IHPA1A_Test_LHW_01_7.jpg_  Null   Null
# 7   1106_object_list.json   20IHPA1A_Test_LHW_01_8.jpg_  1280    720
# 8   1106_object_list.json   20IHPA1A_Test_LHW_01_9.jpg_  Null   Null
# 9   1106_object_list.json  20IHPA1A_Test_LHW_01_10.jpg_  1280    720
# 10  1106_object_list.json  20IHPA1A_Test_LHW_01_11.jpg_  1280    720
# 11  1106_object_list.json  20IHPA1A_Test_LHW_01_12.jpg_  1280    720
#
#             obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0               Null     Null     Null     Null     Null    Null    Null
# 1   grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2   grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3   grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4               Null     Null     Null     Null     Null    Null    Null
# 5               Null     Null     Null     Null     Null    Null    Null
# 6               Null     Null     Null     Null     Null    Null    Null
# 7   grab_bottle_body  400.512  19.4904  982.912  401.256  0.8019       8
# 8               Null     Null     Null     Null     Null    Null    Null
# 9   grab_bottle_body      432   23.688  1061.38  371.232  0.9973       8
# 10  grab_bottle_body  422.656  27.7056  1044.74  364.608  0.9995       8
# 11  grab_bottle_body  444.416   15.804  1106.69      351  0.9928       8
# ['0']
# {'obj': 8, 'name': 'grab_bottle_body', 'score': 0.9996, 'bbox': [19.8936, 434.304, 362.808, 1102.464], 'size': [1280, 720]}
#               json_source                      filename width height  \
# 0   1106_object_list.json   20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1   1106_object_list.json   20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2   1106_object_list.json   20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3   1106_object_list.json   20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4   1106_object_list.json   20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# 5   1106_object_list.json   20IHPA1A_Test_LHW_01_6.jpg_  Null   Null
# 6   1106_object_list.json   20IHPA1A_Test_LHW_01_7.jpg_  Null   Null
# 7   1106_object_list.json   20IHPA1A_Test_LHW_01_8.jpg_  1280    720
# 8   1106_object_list.json   20IHPA1A_Test_LHW_01_9.jpg_  Null   Null
# 9   1106_object_list.json  20IHPA1A_Test_LHW_01_10.jpg_  1280    720
# 10  1106_object_list.json  20IHPA1A_Test_LHW_01_11.jpg_  1280    720
# 11  1106_object_list.json  20IHPA1A_Test_LHW_01_12.jpg_  1280    720
# 12  1106_object_list.json  20IHPA1A_Test_LHW_01_13.jpg_  1280    720
#
#             obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0               Null     Null     Null     Null     Null    Null    Null
# 1   grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2   grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3   grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4               Null     Null     Null     Null     Null    Null    Null
# 5               Null     Null     Null     Null     Null    Null    Null
# 6               Null     Null     Null     Null     Null    Null    Null
# 7   grab_bottle_body  400.512  19.4904  982.912  401.256  0.8019       8
# 8               Null     Null     Null     Null     Null    Null    Null
# 9   grab_bottle_body      432   23.688  1061.38  371.232  0.9973       8
# 10  grab_bottle_body  422.656  27.7056  1044.74  364.608  0.9995       8
# 11  grab_bottle_body  444.416   15.804  1106.69      351  0.9928       8
# 12  grab_bottle_body  434.304  19.8936  1102.46  362.808  0.9996       8
# ['0']
# {'obj': 8, 'name': 'grab_bottle_body', 'score': 0.9596, 'bbox': [30.844800000000003, 415.616, 372.24, 1021.0559999999999], 'size': [1280, 720]}
#               json_source                      filename width height  \
# 0   1106_object_list.json   20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1   1106_object_list.json   20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2   1106_object_list.json   20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3   1106_object_list.json   20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4   1106_object_list.json   20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# 5   1106_object_list.json   20IHPA1A_Test_LHW_01_6.jpg_  Null   Null
# 6   1106_object_list.json   20IHPA1A_Test_LHW_01_7.jpg_  Null   Null
# 7   1106_object_list.json   20IHPA1A_Test_LHW_01_8.jpg_  1280    720
# 8   1106_object_list.json   20IHPA1A_Test_LHW_01_9.jpg_  Null   Null
# 9   1106_object_list.json  20IHPA1A_Test_LHW_01_10.jpg_  1280    720
# 10  1106_object_list.json  20IHPA1A_Test_LHW_01_11.jpg_  1280    720
# 11  1106_object_list.json  20IHPA1A_Test_LHW_01_12.jpg_  1280    720
# 12  1106_object_list.json  20IHPA1A_Test_LHW_01_13.jpg_  1280    720
# 13  1106_object_list.json  20IHPA1A_Test_LHW_01_14.jpg_  1280    720
#
#             obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0               Null     Null     Null     Null     Null    Null    Null
# 1   grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2   grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3   grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4               Null     Null     Null     Null     Null    Null    Null
# 5               Null     Null     Null     Null     Null    Null    Null
# 6               Null     Null     Null     Null     Null    Null    Null
# 7   grab_bottle_body  400.512  19.4904  982.912  401.256  0.8019       8
# 8               Null     Null     Null     Null     Null    Null    Null
# 9   grab_bottle_body      432   23.688  1061.38  371.232  0.9973       8
# 10  grab_bottle_body  422.656  27.7056  1044.74  364.608  0.9995       8
# 11  grab_bottle_body  444.416   15.804  1106.69      351  0.9928       8
# 12  grab_bottle_body  434.304  19.8936  1102.46  362.808  0.9996       8
# 13  grab_bottle_body  415.616  30.8448  1021.06   372.24  0.9596       8
# ['0']
# {'obj': 8, 'name': 'grab_bottle_body', 'score': 0.8895, 'bbox': [21.0744, 408.448, 360.72, 1024.768], 'size': [1280, 720]}
#               json_source                      filename width height  \
# 0   1106_object_list.json   20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1   1106_object_list.json   20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2   1106_object_list.json   20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3   1106_object_list.json   20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4   1106_object_list.json   20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# 5   1106_object_list.json   20IHPA1A_Test_LHW_01_6.jpg_  Null   Null
# 6   1106_object_list.json   20IHPA1A_Test_LHW_01_7.jpg_  Null   Null
# 7   1106_object_list.json   20IHPA1A_Test_LHW_01_8.jpg_  1280    720
# 8   1106_object_list.json   20IHPA1A_Test_LHW_01_9.jpg_  Null   Null
# 9   1106_object_list.json  20IHPA1A_Test_LHW_01_10.jpg_  1280    720
# 10  1106_object_list.json  20IHPA1A_Test_LHW_01_11.jpg_  1280    720
# 11  1106_object_list.json  20IHPA1A_Test_LHW_01_12.jpg_  1280    720
# 12  1106_object_list.json  20IHPA1A_Test_LHW_01_13.jpg_  1280    720
# 13  1106_object_list.json  20IHPA1A_Test_LHW_01_14.jpg_  1280    720
# 14  1106_object_list.json  20IHPA1A_Test_LHW_01_15.jpg_  1280    720
#
#             obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0               Null     Null     Null     Null     Null    Null    Null
# 1   grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2   grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3   grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4               Null     Null     Null     Null     Null    Null    Null
# 5               Null     Null     Null     Null     Null    Null    Null
# 6               Null     Null     Null     Null     Null    Null    Null
# 7   grab_bottle_body  400.512  19.4904  982.912  401.256  0.8019       8
# 8               Null     Null     Null     Null     Null    Null    Null
# 9   grab_bottle_body      432   23.688  1061.38  371.232  0.9973       8
# 10  grab_bottle_body  422.656  27.7056  1044.74  364.608  0.9995       8
# 11  grab_bottle_body  444.416   15.804  1106.69      351  0.9928       8
# 12  grab_bottle_body  434.304  19.8936  1102.46  362.808  0.9996       8
# 13  grab_bottle_body  415.616  30.8448  1021.06   372.24  0.9596       8
# 14  grab_bottle_body  408.448  21.0744  1024.77   360.72  0.8895       8
# ['0']
# {'obj': 8, 'name': 'grab_bottle_body', 'score': 0.9957, 'bbox': [8.1288, 443.00800000000004, 351.792, 991.6160000000001], 'size': [1280, 720]}
#               json_source                      filename width height  \
# 0   1106_object_list.json   20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1   1106_object_list.json   20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2   1106_object_list.json   20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3   1106_object_list.json   20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4   1106_object_list.json   20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# 5   1106_object_list.json   20IHPA1A_Test_LHW_01_6.jpg_  Null   Null
# 6   1106_object_list.json   20IHPA1A_Test_LHW_01_7.jpg_  Null   Null
# 7   1106_object_list.json   20IHPA1A_Test_LHW_01_8.jpg_  1280    720
# 8   1106_object_list.json   20IHPA1A_Test_LHW_01_9.jpg_  Null   Null
# 9   1106_object_list.json  20IHPA1A_Test_LHW_01_10.jpg_  1280    720
# 10  1106_object_list.json  20IHPA1A_Test_LHW_01_11.jpg_  1280    720
# 11  1106_object_list.json  20IHPA1A_Test_LHW_01_12.jpg_  1280    720
# 12  1106_object_list.json  20IHPA1A_Test_LHW_01_13.jpg_  1280    720
# 13  1106_object_list.json  20IHPA1A_Test_LHW_01_14.jpg_  1280    720
# 14  1106_object_list.json  20IHPA1A_Test_LHW_01_15.jpg_  1280    720
# 15  1106_object_list.json  20IHPA1A_Test_LHW_01_16.jpg_  1280    720
#
#             obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0               Null     Null     Null     Null     Null    Null    Null
# 1   grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2   grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3   grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4               Null     Null     Null     Null     Null    Null    Null
# 5               Null     Null     Null     Null     Null    Null    Null
# 6               Null     Null     Null     Null     Null    Null    Null
# 7   grab_bottle_body  400.512  19.4904  982.912  401.256  0.8019       8
# 8               Null     Null     Null     Null     Null    Null    Null
# 9   grab_bottle_body      432   23.688  1061.38  371.232  0.9973       8
# 10  grab_bottle_body  422.656  27.7056  1044.74  364.608  0.9995       8
# 11  grab_bottle_body  444.416   15.804  1106.69      351  0.9928       8
# 12  grab_bottle_body  434.304  19.8936  1102.46  362.808  0.9996       8
# 13  grab_bottle_body  415.616  30.8448  1021.06   372.24  0.9596       8
# 14  grab_bottle_body  408.448  21.0744  1024.77   360.72  0.8895       8
# 15  grab_bottle_body  443.008   8.1288  991.616  351.792  0.9957       8
# ['0']
# {'obj': 8, 'name': 'grab_bottle_body', 'score': 0.9995, 'bbox': [23.003999999999998, 451.456, 364.824, 1069.3120000000001], 'size': [1280, 720]}
#               json_source                      filename width height  \
# 0   1106_object_list.json   20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1   1106_object_list.json   20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2   1106_object_list.json   20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3   1106_object_list.json   20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4   1106_object_list.json   20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# 5   1106_object_list.json   20IHPA1A_Test_LHW_01_6.jpg_  Null   Null
# 6   1106_object_list.json   20IHPA1A_Test_LHW_01_7.jpg_  Null   Null
# 7   1106_object_list.json   20IHPA1A_Test_LHW_01_8.jpg_  1280    720
# 8   1106_object_list.json   20IHPA1A_Test_LHW_01_9.jpg_  Null   Null
# 9   1106_object_list.json  20IHPA1A_Test_LHW_01_10.jpg_  1280    720
# 10  1106_object_list.json  20IHPA1A_Test_LHW_01_11.jpg_  1280    720
# 11  1106_object_list.json  20IHPA1A_Test_LHW_01_12.jpg_  1280    720
# 12  1106_object_list.json  20IHPA1A_Test_LHW_01_13.jpg_  1280    720
# 13  1106_object_list.json  20IHPA1A_Test_LHW_01_14.jpg_  1280    720
# 14  1106_object_list.json  20IHPA1A_Test_LHW_01_15.jpg_  1280    720
# 15  1106_object_list.json  20IHPA1A_Test_LHW_01_16.jpg_  1280    720
# 16  1106_object_list.json  20IHPA1A_Test_LHW_01_17.jpg_  1280    720
#
#             obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0               Null     Null     Null     Null     Null    Null    Null
# 1   grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2   grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3   grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4               Null     Null     Null     Null     Null    Null    Null
# 5               Null     Null     Null     Null     Null    Null    Null
# 6               Null     Null     Null     Null     Null    Null    Null
# 7   grab_bottle_body  400.512  19.4904  982.912  401.256  0.8019       8
# 8               Null     Null     Null     Null     Null    Null    Null
# 9   grab_bottle_body      432   23.688  1061.38  371.232  0.9973       8
# 10  grab_bottle_body  422.656  27.7056  1044.74  364.608  0.9995       8
# 11  grab_bottle_body  444.416   15.804  1106.69      351  0.9928       8
# 12  grab_bottle_body  434.304  19.8936  1102.46  362.808  0.9996       8
# 13  grab_bottle_body  415.616  30.8448  1021.06   372.24  0.9596       8
# 14  grab_bottle_body  408.448  21.0744  1024.77   360.72  0.8895       8
# 15  grab_bottle_body  443.008   8.1288  991.616  351.792  0.9957       8
# 16  grab_bottle_body  451.456   23.004  1069.31  364.824  0.9995       8
# ['0']
# {'obj': 8, 'name': 'grab_bottle_body', 'score': 0.9982, 'bbox': [25.106399999999997, 440.576, 365.328, 1105.152], 'size': [1280, 720]}
#               json_source                      filename width height  \
# 0   1106_object_list.json   20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1   1106_object_list.json   20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2   1106_object_list.json   20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3   1106_object_list.json   20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4   1106_object_list.json   20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# 5   1106_object_list.json   20IHPA1A_Test_LHW_01_6.jpg_  Null   Null
# 6   1106_object_list.json   20IHPA1A_Test_LHW_01_7.jpg_  Null   Null
# 7   1106_object_list.json   20IHPA1A_Test_LHW_01_8.jpg_  1280    720
# 8   1106_object_list.json   20IHPA1A_Test_LHW_01_9.jpg_  Null   Null
# 9   1106_object_list.json  20IHPA1A_Test_LHW_01_10.jpg_  1280    720
# 10  1106_object_list.json  20IHPA1A_Test_LHW_01_11.jpg_  1280    720
# 11  1106_object_list.json  20IHPA1A_Test_LHW_01_12.jpg_  1280    720
# 12  1106_object_list.json  20IHPA1A_Test_LHW_01_13.jpg_  1280    720
# 13  1106_object_list.json  20IHPA1A_Test_LHW_01_14.jpg_  1280    720
# 14  1106_object_list.json  20IHPA1A_Test_LHW_01_15.jpg_  1280    720
# 15  1106_object_list.json  20IHPA1A_Test_LHW_01_16.jpg_  1280    720
# 16  1106_object_list.json  20IHPA1A_Test_LHW_01_17.jpg_  1280    720
# 17  1106_object_list.json  20IHPA1A_Test_LHW_01_18.jpg_  1280    720
#
#             obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0               Null     Null     Null     Null     Null    Null    Null
# 1   grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2   grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3   grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4               Null     Null     Null     Null     Null    Null    Null
# 5               Null     Null     Null     Null     Null    Null    Null
# 6               Null     Null     Null     Null     Null    Null    Null
# 7   grab_bottle_body  400.512  19.4904  982.912  401.256  0.8019       8
# 8               Null     Null     Null     Null     Null    Null    Null
# 9   grab_bottle_body      432   23.688  1061.38  371.232  0.9973       8
# 10  grab_bottle_body  422.656  27.7056  1044.74  364.608  0.9995       8
# 11  grab_bottle_body  444.416   15.804  1106.69      351  0.9928       8
# 12  grab_bottle_body  434.304  19.8936  1102.46  362.808  0.9996       8
# 13  grab_bottle_body  415.616  30.8448  1021.06   372.24  0.9596       8
# 14  grab_bottle_body  408.448  21.0744  1024.77   360.72  0.8895       8
# 15  grab_bottle_body  443.008   8.1288  991.616  351.792  0.9957       8
# 16  grab_bottle_body  451.456   23.004  1069.31  364.824  0.9995       8
# 17  grab_bottle_body  440.576  25.1064  1105.15  365.328  0.9982       8
# ['0']
# {'obj': 8, 'name': 'grab_bottle_body', 'score': 0.9881, 'bbox': [26.6472, 434.56000000000006, 365.54400000000004, 1107.8400000000001], 'size': [1280, 720]}
#               json_source                      filename width height  \
# 0   1106_object_list.json   20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1   1106_object_list.json   20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2   1106_object_list.json   20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3   1106_object_list.json   20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4   1106_object_list.json   20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# 5   1106_object_list.json   20IHPA1A_Test_LHW_01_6.jpg_  Null   Null
# 6   1106_object_list.json   20IHPA1A_Test_LHW_01_7.jpg_  Null   Null
# 7   1106_object_list.json   20IHPA1A_Test_LHW_01_8.jpg_  1280    720
# 8   1106_object_list.json   20IHPA1A_Test_LHW_01_9.jpg_  Null   Null
# 9   1106_object_list.json  20IHPA1A_Test_LHW_01_10.jpg_  1280    720
# 10  1106_object_list.json  20IHPA1A_Test_LHW_01_11.jpg_  1280    720
# 11  1106_object_list.json  20IHPA1A_Test_LHW_01_12.jpg_  1280    720
# 12  1106_object_list.json  20IHPA1A_Test_LHW_01_13.jpg_  1280    720
# 13  1106_object_list.json  20IHPA1A_Test_LHW_01_14.jpg_  1280    720
# 14  1106_object_list.json  20IHPA1A_Test_LHW_01_15.jpg_  1280    720
# 15  1106_object_list.json  20IHPA1A_Test_LHW_01_16.jpg_  1280    720
# 16  1106_object_list.json  20IHPA1A_Test_LHW_01_17.jpg_  1280    720
# 17  1106_object_list.json  20IHPA1A_Test_LHW_01_18.jpg_  1280    720
# 18  1106_object_list.json  20IHPA1A_Test_LHW_01_19.jpg_  1280    720
#
#             obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0               Null     Null     Null     Null     Null    Null    Null
# 1   grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2   grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3   grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4               Null     Null     Null     Null     Null    Null    Null
# 5               Null     Null     Null     Null     Null    Null    Null
# 6               Null     Null     Null     Null     Null    Null    Null
# 7   grab_bottle_body  400.512  19.4904  982.912  401.256  0.8019       8
# 8               Null     Null     Null     Null     Null    Null    Null
# 9   grab_bottle_body      432   23.688  1061.38  371.232  0.9973       8
# 10  grab_bottle_body  422.656  27.7056  1044.74  364.608  0.9995       8
# 11  grab_bottle_body  444.416   15.804  1106.69      351  0.9928       8
# 12  grab_bottle_body  434.304  19.8936  1102.46  362.808  0.9996       8
# 13  grab_bottle_body  415.616  30.8448  1021.06   372.24  0.9596       8
# 14  grab_bottle_body  408.448  21.0744  1024.77   360.72  0.8895       8
# 15  grab_bottle_body  443.008   8.1288  991.616  351.792  0.9957       8
# 16  grab_bottle_body  451.456   23.004  1069.31  364.824  0.9995       8
# 17  grab_bottle_body  440.576  25.1064  1105.15  365.328  0.9982       8
# 18  grab_bottle_body   434.56  26.6472  1107.84  365.544  0.9881       8
#               json_source                      filename width height  \
# 0   1106_object_list.json   20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1   1106_object_list.json   20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2   1106_object_list.json   20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3   1106_object_list.json   20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4   1106_object_list.json   20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# 5   1106_object_list.json   20IHPA1A_Test_LHW_01_6.jpg_  Null   Null
# 6   1106_object_list.json   20IHPA1A_Test_LHW_01_7.jpg_  Null   Null
# 7   1106_object_list.json   20IHPA1A_Test_LHW_01_8.jpg_  1280    720
# 8   1106_object_list.json   20IHPA1A_Test_LHW_01_9.jpg_  Null   Null
# 9   1106_object_list.json  20IHPA1A_Test_LHW_01_10.jpg_  1280    720
# 10  1106_object_list.json  20IHPA1A_Test_LHW_01_11.jpg_  1280    720
# 11  1106_object_list.json  20IHPA1A_Test_LHW_01_12.jpg_  1280    720
# 12  1106_object_list.json  20IHPA1A_Test_LHW_01_13.jpg_  1280    720
# 13  1106_object_list.json  20IHPA1A_Test_LHW_01_14.jpg_  1280    720
# 14  1106_object_list.json  20IHPA1A_Test_LHW_01_15.jpg_  1280    720
# 15  1106_object_list.json  20IHPA1A_Test_LHW_01_16.jpg_  1280    720
# 16  1106_object_list.json  20IHPA1A_Test_LHW_01_17.jpg_  1280    720
# 17  1106_object_list.json  20IHPA1A_Test_LHW_01_18.jpg_  1280    720
# 18  1106_object_list.json  20IHPA1A_Test_LHW_01_19.jpg_  1280    720
# 19  1106_object_list.json  20IHPA1A_Test_LHW_01_20.jpg_  Null   Null
#
#             obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0               Null     Null     Null     Null     Null    Null    Null
# 1   grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2   grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3   grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4               Null     Null     Null     Null     Null    Null    Null
# 5               Null     Null     Null     Null     Null    Null    Null
# 6               Null     Null     Null     Null     Null    Null    Null
# 7   grab_bottle_body  400.512  19.4904  982.912  401.256  0.8019       8
# 8               Null     Null     Null     Null     Null    Null    Null
# 9   grab_bottle_body      432   23.688  1061.38  371.232  0.9973       8
# 10  grab_bottle_body  422.656  27.7056  1044.74  364.608  0.9995       8
# 11  grab_bottle_body  444.416   15.804  1106.69      351  0.9928       8
# 12  grab_bottle_body  434.304  19.8936  1102.46  362.808  0.9996       8
# 13  grab_bottle_body  415.616  30.8448  1021.06   372.24  0.9596       8
# 14  grab_bottle_body  408.448  21.0744  1024.77   360.72  0.8895       8
# 15  grab_bottle_body  443.008   8.1288  991.616  351.792  0.9957       8
# 16  grab_bottle_body  451.456   23.004  1069.31  364.824  0.9995       8
# 17  grab_bottle_body  440.576  25.1064  1105.15  365.328  0.9982       8
# 18  grab_bottle_body   434.56  26.6472  1107.84  365.544  0.9881       8
# 19              Null     Null     Null     Null     Null    Null    Null
#               json_source                      filename width height  \
# 0   1106_object_list.json   20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1   1106_object_list.json   20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2   1106_object_list.json   20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3   1106_object_list.json   20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4   1106_object_list.json   20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# 5   1106_object_list.json   20IHPA1A_Test_LHW_01_6.jpg_  Null   Null
# 6   1106_object_list.json   20IHPA1A_Test_LHW_01_7.jpg_  Null   Null
# 7   1106_object_list.json   20IHPA1A_Test_LHW_01_8.jpg_  1280    720
# 8   1106_object_list.json   20IHPA1A_Test_LHW_01_9.jpg_  Null   Null
# 9   1106_object_list.json  20IHPA1A_Test_LHW_01_10.jpg_  1280    720
# 10  1106_object_list.json  20IHPA1A_Test_LHW_01_11.jpg_  1280    720
# 11  1106_object_list.json  20IHPA1A_Test_LHW_01_12.jpg_  1280    720
# 12  1106_object_list.json  20IHPA1A_Test_LHW_01_13.jpg_  1280    720
# 13  1106_object_list.json  20IHPA1A_Test_LHW_01_14.jpg_  1280    720
# 14  1106_object_list.json  20IHPA1A_Test_LHW_01_15.jpg_  1280    720
# 15  1106_object_list.json  20IHPA1A_Test_LHW_01_16.jpg_  1280    720
# 16  1106_object_list.json  20IHPA1A_Test_LHW_01_17.jpg_  1280    720
# 17  1106_object_list.json  20IHPA1A_Test_LHW_01_18.jpg_  1280    720
# 18  1106_object_list.json  20IHPA1A_Test_LHW_01_19.jpg_  1280    720
# 19  1106_object_list.json  20IHPA1A_Test_LHW_01_20.jpg_  Null   Null
# 20  1106_object_list.json  20IHPA1A_Test_LHW_01_21.jpg_  Null   Null
#
#             obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0               Null     Null     Null     Null     Null    Null    Null
# 1   grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2   grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3   grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4               Null     Null     Null     Null     Null    Null    Null
# 5               Null     Null     Null     Null     Null    Null    Null
# 6               Null     Null     Null     Null     Null    Null    Null
# 7   grab_bottle_body  400.512  19.4904  982.912  401.256  0.8019       8
# 8               Null     Null     Null     Null     Null    Null    Null
# 9   grab_bottle_body      432   23.688  1061.38  371.232  0.9973       8
# 10  grab_bottle_body  422.656  27.7056  1044.74  364.608  0.9995       8
# 11  grab_bottle_body  444.416   15.804  1106.69      351  0.9928       8
# 12  grab_bottle_body  434.304  19.8936  1102.46  362.808  0.9996       8
# 13  grab_bottle_body  415.616  30.8448  1021.06   372.24  0.9596       8
# 14  grab_bottle_body  408.448  21.0744  1024.77   360.72  0.8895       8
# 15  grab_bottle_body  443.008   8.1288  991.616  351.792  0.9957       8
# 16  grab_bottle_body  451.456   23.004  1069.31  364.824  0.9995       8
# 17  grab_bottle_body  440.576  25.1064  1105.15  365.328  0.9982       8
# 18  grab_bottle_body   434.56  26.6472  1107.84  365.544  0.9881       8
# 19              Null     Null     Null     Null     Null    Null    Null
# 20              Null     Null     Null     Null     Null    Null    Null
#               json_source                      filename width height  \
# 0   1106_object_list.json   20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1   1106_object_list.json   20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2   1106_object_list.json   20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3   1106_object_list.json   20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4   1106_object_list.json   20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# 5   1106_object_list.json   20IHPA1A_Test_LHW_01_6.jpg_  Null   Null
# 6   1106_object_list.json   20IHPA1A_Test_LHW_01_7.jpg_  Null   Null
# 7   1106_object_list.json   20IHPA1A_Test_LHW_01_8.jpg_  1280    720
# 8   1106_object_list.json   20IHPA1A_Test_LHW_01_9.jpg_  Null   Null
# 9   1106_object_list.json  20IHPA1A_Test_LHW_01_10.jpg_  1280    720
# 10  1106_object_list.json  20IHPA1A_Test_LHW_01_11.jpg_  1280    720
# 11  1106_object_list.json  20IHPA1A_Test_LHW_01_12.jpg_  1280    720
# 12  1106_object_list.json  20IHPA1A_Test_LHW_01_13.jpg_  1280    720
# 13  1106_object_list.json  20IHPA1A_Test_LHW_01_14.jpg_  1280    720
# 14  1106_object_list.json  20IHPA1A_Test_LHW_01_15.jpg_  1280    720
# 15  1106_object_list.json  20IHPA1A_Test_LHW_01_16.jpg_  1280    720
# 16  1106_object_list.json  20IHPA1A_Test_LHW_01_17.jpg_  1280    720
# 17  1106_object_list.json  20IHPA1A_Test_LHW_01_18.jpg_  1280    720
# 18  1106_object_list.json  20IHPA1A_Test_LHW_01_19.jpg_  1280    720
# 19  1106_object_list.json  20IHPA1A_Test_LHW_01_20.jpg_  Null   Null
# 20  1106_object_list.json  20IHPA1A_Test_LHW_01_21.jpg_  Null   Null
# 21  1106_object_list.json  20IHPA1A_Test_LHW_01_22.jpg_  Null   Null
#
#             obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0               Null     Null     Null     Null     Null    Null    Null
# 1   grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2   grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3   grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4               Null     Null     Null     Null     Null    Null    Null
# 5               Null     Null     Null     Null     Null    Null    Null
# 6               Null     Null     Null     Null     Null    Null    Null
# 7   grab_bottle_body  400.512  19.4904  982.912  401.256  0.8019       8
# 8               Null     Null     Null     Null     Null    Null    Null
# 9   grab_bottle_body      432   23.688  1061.38  371.232  0.9973       8
# 10  grab_bottle_body  422.656  27.7056  1044.74  364.608  0.9995       8
# 11  grab_bottle_body  444.416   15.804  1106.69      351  0.9928       8
# 12  grab_bottle_body  434.304  19.8936  1102.46  362.808  0.9996       8
# 13  grab_bottle_body  415.616  30.8448  1021.06   372.24  0.9596       8
# 14  grab_bottle_body  408.448  21.0744  1024.77   360.72  0.8895       8
# 15  grab_bottle_body  443.008   8.1288  991.616  351.792  0.9957       8
# 16  grab_bottle_body  451.456   23.004  1069.31  364.824  0.9995       8
# 17  grab_bottle_body  440.576  25.1064  1105.15  365.328  0.9982       8
# 18  grab_bottle_body   434.56  26.6472  1107.84  365.544  0.9881       8
# 19              Null     Null     Null     Null     Null    Null    Null
# 20              Null     Null     Null     Null     Null    Null    Null
# 21              Null     Null     Null     Null     Null    Null    Null
#               json_source                      filename width height  \
# 0   1106_object_list.json   20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1   1106_object_list.json   20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2   1106_object_list.json   20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3   1106_object_list.json   20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4   1106_object_list.json   20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# 5   1106_object_list.json   20IHPA1A_Test_LHW_01_6.jpg_  Null   Null
# 6   1106_object_list.json   20IHPA1A_Test_LHW_01_7.jpg_  Null   Null
# 7   1106_object_list.json   20IHPA1A_Test_LHW_01_8.jpg_  1280    720
# 8   1106_object_list.json   20IHPA1A_Test_LHW_01_9.jpg_  Null   Null
# 9   1106_object_list.json  20IHPA1A_Test_LHW_01_10.jpg_  1280    720
# 10  1106_object_list.json  20IHPA1A_Test_LHW_01_11.jpg_  1280    720
# 11  1106_object_list.json  20IHPA1A_Test_LHW_01_12.jpg_  1280    720
# 12  1106_object_list.json  20IHPA1A_Test_LHW_01_13.jpg_  1280    720
# 13  1106_object_list.json  20IHPA1A_Test_LHW_01_14.jpg_  1280    720
# 14  1106_object_list.json  20IHPA1A_Test_LHW_01_15.jpg_  1280    720
# 15  1106_object_list.json  20IHPA1A_Test_LHW_01_16.jpg_  1280    720
# 16  1106_object_list.json  20IHPA1A_Test_LHW_01_17.jpg_  1280    720
# 17  1106_object_list.json  20IHPA1A_Test_LHW_01_18.jpg_  1280    720
# 18  1106_object_list.json  20IHPA1A_Test_LHW_01_19.jpg_  1280    720
# 19  1106_object_list.json  20IHPA1A_Test_LHW_01_20.jpg_  Null   Null
# 20  1106_object_list.json  20IHPA1A_Test_LHW_01_21.jpg_  Null   Null
# 21  1106_object_list.json  20IHPA1A_Test_LHW_01_22.jpg_  Null   Null
# 22  1106_object_list.json  20IHPA1A_Test_LHW_01_23.jpg_  Null   Null
#
#             obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0               Null     Null     Null     Null     Null    Null    Null
# 1   grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2   grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3   grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4               Null     Null     Null     Null     Null    Null    Null
# 5               Null     Null     Null     Null     Null    Null    Null
# 6               Null     Null     Null     Null     Null    Null    Null
# 7   grab_bottle_body  400.512  19.4904  982.912  401.256  0.8019       8
# 8               Null     Null     Null     Null     Null    Null    Null
# 9   grab_bottle_body      432   23.688  1061.38  371.232  0.9973       8
# 10  grab_bottle_body  422.656  27.7056  1044.74  364.608  0.9995       8
# 11  grab_bottle_body  444.416   15.804  1106.69      351  0.9928       8
# 12  grab_bottle_body  434.304  19.8936  1102.46  362.808  0.9996       8
# 13  grab_bottle_body  415.616  30.8448  1021.06   372.24  0.9596       8
# 14  grab_bottle_body  408.448  21.0744  1024.77   360.72  0.8895       8
# 15  grab_bottle_body  443.008   8.1288  991.616  351.792  0.9957       8
# 16  grab_bottle_body  451.456   23.004  1069.31  364.824  0.9995       8
# 17  grab_bottle_body  440.576  25.1064  1105.15  365.328  0.9982       8
# 18  grab_bottle_body   434.56  26.6472  1107.84  365.544  0.9881       8
# 19              Null     Null     Null     Null     Null    Null    Null
# 20              Null     Null     Null     Null     Null    Null    Null
# 21              Null     Null     Null     Null     Null    Null    Null
# 22              Null     Null     Null     Null     Null    Null    Null
#               json_source                      filename width height  \
# 0   1106_object_list.json   20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1   1106_object_list.json   20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2   1106_object_list.json   20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3   1106_object_list.json   20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4   1106_object_list.json   20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# 5   1106_object_list.json   20IHPA1A_Test_LHW_01_6.jpg_  Null   Null
# 6   1106_object_list.json   20IHPA1A_Test_LHW_01_7.jpg_  Null   Null
# 7   1106_object_list.json   20IHPA1A_Test_LHW_01_8.jpg_  1280    720
# 8   1106_object_list.json   20IHPA1A_Test_LHW_01_9.jpg_  Null   Null
# 9   1106_object_list.json  20IHPA1A_Test_LHW_01_10.jpg_  1280    720
# 10  1106_object_list.json  20IHPA1A_Test_LHW_01_11.jpg_  1280    720
# 11  1106_object_list.json  20IHPA1A_Test_LHW_01_12.jpg_  1280    720
# 12  1106_object_list.json  20IHPA1A_Test_LHW_01_13.jpg_  1280    720
# 13  1106_object_list.json  20IHPA1A_Test_LHW_01_14.jpg_  1280    720
# 14  1106_object_list.json  20IHPA1A_Test_LHW_01_15.jpg_  1280    720
# 15  1106_object_list.json  20IHPA1A_Test_LHW_01_16.jpg_  1280    720
# 16  1106_object_list.json  20IHPA1A_Test_LHW_01_17.jpg_  1280    720
# 17  1106_object_list.json  20IHPA1A_Test_LHW_01_18.jpg_  1280    720
# 18  1106_object_list.json  20IHPA1A_Test_LHW_01_19.jpg_  1280    720
# 19  1106_object_list.json  20IHPA1A_Test_LHW_01_20.jpg_  Null   Null
# 20  1106_object_list.json  20IHPA1A_Test_LHW_01_21.jpg_  Null   Null
# 21  1106_object_list.json  20IHPA1A_Test_LHW_01_22.jpg_  Null   Null
# 22  1106_object_list.json  20IHPA1A_Test_LHW_01_23.jpg_  Null   Null
# 23  1106_object_list.json  20IHPA1A_Test_LHW_01_24.jpg_  Null   Null
#
#             obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0               Null     Null     Null     Null     Null    Null    Null
# 1   grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2   grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3   grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4               Null     Null     Null     Null     Null    Null    Null
# ...
# ..                     ...                            ...   ...    ...
# 488  1106_object_list.json  20IHPA1A_Test_LHW_01_488.jpg_  Null   Null
# 489  1106_object_list.json  20IHPA1A_Test_LHW_01_489.jpg_  Null   Null
# 490  1106_object_list.json  20IHPA1A_Test_LHW_01_490.jpg_  Null   Null
# 491  1106_object_list.json  20IHPA1A_Test_LHW_01_491.jpg_  Null   Null
# 492  1106_object_list.json  20IHPA1A_Test_LHW_01_492.jpg_  Null   Null
#
#              obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0                Null     Null     Null     Null     Null    Null    Null
# 1    grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2    grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3    grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4                Null     Null     Null     Null     Null    Null    Null
# ..                ...      ...      ...      ...      ...     ...     ...
# 488              Null     Null     Null     Null     Null    Null    Null
# 489              Null     Null     Null     Null     Null    Null    Null
# 490              Null     Null     Null     Null     Null    Null    Null
# 491              Null     Null     Null     Null     Null    Null    Null
# 492              Null     Null     Null     Null     Null    Null    Null
#
# [493 rows x 11 columns]
#                json_source                       filename width height  \
# 0    1106_object_list.json    20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1    1106_object_list.json    20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2    1106_object_list.json    20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3    1106_object_list.json    20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4    1106_object_list.json    20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# ..                     ...                            ...   ...    ...
# 489  1106_object_list.json  20IHPA1A_Test_LHW_01_489.jpg_  Null   Null
# 490  1106_object_list.json  20IHPA1A_Test_LHW_01_490.jpg_  Null   Null
# 491  1106_object_list.json  20IHPA1A_Test_LHW_01_491.jpg_  Null   Null
# 492  1106_object_list.json  20IHPA1A_Test_LHW_01_492.jpg_  Null   Null
# 493  1106_object_list.json  20IHPA1A_Test_LHW_01_493.jpg_  Null   Null
#
#              obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0                Null     Null     Null     Null     Null    Null    Null
# 1    grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2    grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3    grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4                Null     Null     Null     Null     Null    Null    Null
# ..                ...      ...      ...      ...      ...     ...     ...
# 489              Null     Null     Null     Null     Null    Null    Null
# 490              Null     Null     Null     Null     Null    Null    Null
# 491              Null     Null     Null     Null     Null    Null    Null
# 492              Null     Null     Null     Null     Null    Null    Null
# 493              Null     Null     Null     Null     Null    Null    Null
#
# [494 rows x 11 columns]
#                json_source                       filename width height  \
# 0    1106_object_list.json    20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1    1106_object_list.json    20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2    1106_object_list.json    20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3    1106_object_list.json    20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4    1106_object_list.json    20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# ..                     ...                            ...   ...    ...
# 490  1106_object_list.json  20IHPA1A_Test_LHW_01_490.jpg_  Null   Null
# 491  1106_object_list.json  20IHPA1A_Test_LHW_01_491.jpg_  Null   Null
# 492  1106_object_list.json  20IHPA1A_Test_LHW_01_492.jpg_  Null   Null
# 493  1106_object_list.json  20IHPA1A_Test_LHW_01_493.jpg_  Null   Null
# 494  1106_object_list.json  20IHPA1A_Test_LHW_01_494.jpg_  Null   Null
#
#              obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0                Null     Null     Null     Null     Null    Null    Null
# 1    grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2    grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3    grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4                Null     Null     Null     Null     Null    Null    Null
# ..                ...      ...      ...      ...      ...     ...     ...
# 490              Null     Null     Null     Null     Null    Null    Null
# 491              Null     Null     Null     Null     Null    Null    Null
# 492              Null     Null     Null     Null     Null    Null    Null
# 493              Null     Null     Null     Null     Null    Null    Null
# 494              Null     Null     Null     Null     Null    Null    Null
#
# [495 rows x 11 columns]
#                json_source                       filename width height  \
# 0    1106_object_list.json    20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1    1106_object_list.json    20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2    1106_object_list.json    20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3    1106_object_list.json    20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4    1106_object_list.json    20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# ..                     ...                            ...   ...    ...
# 491  1106_object_list.json  20IHPA1A_Test_LHW_01_491.jpg_  Null   Null
# 492  1106_object_list.json  20IHPA1A_Test_LHW_01_492.jpg_  Null   Null
# 493  1106_object_list.json  20IHPA1A_Test_LHW_01_493.jpg_  Null   Null
# 494  1106_object_list.json  20IHPA1A_Test_LHW_01_494.jpg_  Null   Null
# 495  1106_object_list.json  20IHPA1A_Test_LHW_01_495.jpg_  Null   Null
#
#              obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0                Null     Null     Null     Null     Null    Null    Null
# 1    grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2    grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3    grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4                Null     Null     Null     Null     Null    Null    Null
# ..                ...      ...      ...      ...      ...     ...     ...
# 491              Null     Null     Null     Null     Null    Null    Null
# 492              Null     Null     Null     Null     Null    Null    Null
# 493              Null     Null     Null     Null     Null    Null    Null
# 494              Null     Null     Null     Null     Null    Null    Null
# 495              Null     Null     Null     Null     Null    Null    Null
#
# [496 rows x 11 columns]
#                json_source                       filename width height  \
# 0    1106_object_list.json    20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1    1106_object_list.json    20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2    1106_object_list.json    20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3    1106_object_list.json    20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4    1106_object_list.json    20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# ..                     ...                            ...   ...    ...
# 492  1106_object_list.json  20IHPA1A_Test_LHW_01_492.jpg_  Null   Null
# 493  1106_object_list.json  20IHPA1A_Test_LHW_01_493.jpg_  Null   Null
# 494  1106_object_list.json  20IHPA1A_Test_LHW_01_494.jpg_  Null   Null
# 495  1106_object_list.json  20IHPA1A_Test_LHW_01_495.jpg_  Null   Null
# 496  1106_object_list.json  20IHPA1A_Test_LHW_01_496.jpg_  Null   Null
#
#              obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0                Null     Null     Null     Null     Null    Null    Null
# 1    grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2    grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3    grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4                Null     Null     Null     Null     Null    Null    Null
# ..                ...      ...      ...      ...      ...     ...     ...
# 492              Null     Null     Null     Null     Null    Null    Null
# 493              Null     Null     Null     Null     Null    Null    Null
# 494              Null     Null     Null     Null     Null    Null    Null
# 495              Null     Null     Null     Null     Null    Null    Null
# 496              Null     Null     Null     Null     Null    Null    Null
#
# [497 rows x 11 columns]
#                json_source                       filename width height  \
# 0    1106_object_list.json    20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1    1106_object_list.json    20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2    1106_object_list.json    20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3    1106_object_list.json    20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4    1106_object_list.json    20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# ..                     ...                            ...   ...    ...
# 493  1106_object_list.json  20IHPA1A_Test_LHW_01_493.jpg_  Null   Null
# 494  1106_object_list.json  20IHPA1A_Test_LHW_01_494.jpg_  Null   Null
# 495  1106_object_list.json  20IHPA1A_Test_LHW_01_495.jpg_  Null   Null
# 496  1106_object_list.json  20IHPA1A_Test_LHW_01_496.jpg_  Null   Null
# 497  1106_object_list.json  20IHPA1A_Test_LHW_01_497.jpg_  Null   Null
#
#              obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0                Null     Null     Null     Null     Null    Null    Null
# 1    grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2    grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3    grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4                Null     Null     Null     Null     Null    Null    Null
# ..                ...      ...      ...      ...      ...     ...     ...
# 493              Null     Null     Null     Null     Null    Null    Null
# 494              Null     Null     Null     Null     Null    Null    Null
# 495              Null     Null     Null     Null     Null    Null    Null
# 496              Null     Null     Null     Null     Null    Null    Null
# 497              Null     Null     Null     Null     Null    Null    Null
#
# [498 rows x 11 columns]
#                json_source                       filename width height  \
# 0    1106_object_list.json    20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1    1106_object_list.json    20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2    1106_object_list.json    20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3    1106_object_list.json    20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4    1106_object_list.json    20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# ..                     ...                            ...   ...    ...
# 494  1106_object_list.json  20IHPA1A_Test_LHW_01_494.jpg_  Null   Null
# 495  1106_object_list.json  20IHPA1A_Test_LHW_01_495.jpg_  Null   Null
# 496  1106_object_list.json  20IHPA1A_Test_LHW_01_496.jpg_  Null   Null
# 497  1106_object_list.json  20IHPA1A_Test_LHW_01_497.jpg_  Null   Null
# 498  1106_object_list.json  20IHPA1A_Test_LHW_01_498.jpg_  Null   Null
#
#              obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0                Null     Null     Null     Null     Null    Null    Null
# 1    grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2    grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3    grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4                Null     Null     Null     Null     Null    Null    Null
# ..                ...      ...      ...      ...      ...     ...     ...
# 494              Null     Null     Null     Null     Null    Null    Null
# 495              Null     Null     Null     Null     Null    Null    Null
# 496              Null     Null     Null     Null     Null    Null    Null
# 497              Null     Null     Null     Null     Null    Null    Null
# 498              Null     Null     Null     Null     Null    Null    Null
#
# [499 rows x 11 columns]
#                json_source                       filename width height  \
# 0    1106_object_list.json    20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1    1106_object_list.json    20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2    1106_object_list.json    20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3    1106_object_list.json    20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4    1106_object_list.json    20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# ..                     ...                            ...   ...    ...
# 495  1106_object_list.json  20IHPA1A_Test_LHW_01_495.jpg_  Null   Null
# 496  1106_object_list.json  20IHPA1A_Test_LHW_01_496.jpg_  Null   Null
# 497  1106_object_list.json  20IHPA1A_Test_LHW_01_497.jpg_  Null   Null
# 498  1106_object_list.json  20IHPA1A_Test_LHW_01_498.jpg_  Null   Null
# 499  1106_object_list.json  20IHPA1A_Test_LHW_01_499.jpg_  Null   Null
#
#              obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0                Null     Null     Null     Null     Null    Null    Null
# 1    grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2    grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3    grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4                Null     Null     Null     Null     Null    Null    Null
# ..                ...      ...      ...      ...      ...     ...     ...
# 495              Null     Null     Null     Null     Null    Null    Null
# 496              Null     Null     Null     Null     Null    Null    Null
# 497              Null     Null     Null     Null     Null    Null    Null
# 498              Null     Null     Null     Null     Null    Null    Null
# 499              Null     Null     Null     Null     Null    Null    Null
# [500 rows x 11 columns]
#                json_source                       filename width height  \
# 0    1106_object_list.json    20IHPA1A_Test_LHW_01_1.jpg_  Null   Null
# 1    1106_object_list.json    20IHPA1A_Test_LHW_01_2.jpg_  1280    720
# 2    1106_object_list.json    20IHPA1A_Test_LHW_01_3.jpg_  1280    720
# 3    1106_object_list.json    20IHPA1A_Test_LHW_01_4.jpg_  1280    720
# 4    1106_object_list.json    20IHPA1A_Test_LHW_01_5.jpg_  Null   Null
# ..                     ...                            ...   ...    ...
# 496  1106_object_list.json  20IHPA1A_Test_LHW_01_496.jpg_  Null   Null
# 497  1106_object_list.json  20IHPA1A_Test_LHW_01_497.jpg_  Null   Null
# 498  1106_object_list.json  20IHPA1A_Test_LHW_01_498.jpg_  Null   Null
# 499  1106_object_list.json  20IHPA1A_Test_LHW_01_499.jpg_  Null   Null
# 500  1106_object_list.json  20IHPA1A_Test_LHW_01_500.jpg_  Null   Null
#
#              obj_name     xmin     ymin     xmax     ymax   score obj_idx
# 0                Null     Null     Null     Null     Null    Null    Null
# 1    grab_bottle_body  434.304   9.2448  1151.87  318.384   0.952       8
# 2    grab_bottle_body  416.768  5.09616  1085.31  304.488  0.8984       8
# 3    grab_bottle_body  420.224  10.7208  1064.96  310.104  0.8468       8
# 4                Null     Null     Null     Null     Null    Null    Null
# ..                ...      ...      ...      ...      ...     ...     ...
# 496              Null     Null     Null     Null     Null    Null    Null
# 497              Null     Null     Null     Null     Null    Null    Null
# 498              Null     Null     Null     Null     Null    Null    Null
# 499              Null     Null     Null     Null     Null    Null    Null
# 500              Null     Null     Null     Null     Null    Null    Null
#
# [501 rows x 11 columns]

# %%
df['per_obj_cnt'] = np.where(df['obj_idx'] != 'Null' , '1', '0')
df['model'] = 'inhand_20191112'+'_'
df['result_per_obj_id_int'] = df.groupby(['filename','per_obj_cnt']).cumcount()+1
df['result_per_obj_id_str'] = df['result_per_obj_id_int']

'''
apply 쓰기 위해 int-> str 형 변환
'''

df['result_per_obj_id_str'] = df['result_per_obj_id_str'].apply(str)

'''
str 형태만 결합할 수 있음, int형태는 결합 안 됨
https://www.geeksforgeeks.org/create-a-new-column-in-pandas-dataframe-based-on-the-existing-columns/
(참고)
cols = list(df.columns.values)
'''

df['per_obj_pk'] = df.apply(lambda row: row.model + row.filename+ row.result_per_obj_id_str , axis=1)
df = df.reindex(columns=['json_source', 'per_obj_pk', 'model', 'filename', 'result_per_obj_id_str', 'obj_name', 'obj_idx', 'score', 'xmin', 'ymax', 'xmax', 'ymin', 'width', 'height', 'per_obj_cnt', 'result_per_obj_id_int'])

# %%
df
# Out:
#                json_source                                      per_obj_pk  \
# 0    1106_object_list.json    inhand_20191112_20IHPA1A_Test_LHW_01_1.jpg_1
# 1    1106_object_list.json    inhand_20191112_20IHPA1A_Test_LHW_01_2.jpg_1
# 2    1106_object_list.json    inhand_20191112_20IHPA1A_Test_LHW_01_3.jpg_1
# 3    1106_object_list.json    inhand_20191112_20IHPA1A_Test_LHW_01_4.jpg_1
# 4    1106_object_list.json    inhand_20191112_20IHPA1A_Test_LHW_01_5.jpg_1
# ..                     ...                                             ...
# 496  1106_object_list.json  inhand_20191112_20IHPA1A_Test_LHW_01_496.jpg_1
# 497  1106_object_list.json  inhand_20191112_20IHPA1A_Test_LHW_01_497.jpg_1
# 498  1106_object_list.json  inhand_20191112_20IHPA1A_Test_LHW_01_498.jpg_1
# 499  1106_object_list.json  inhand_20191112_20IHPA1A_Test_LHW_01_499.jpg_1
# 500  1106_object_list.json  inhand_20191112_20IHPA1A_Test_LHW_01_500.jpg_1
#
#                 model                       filename result_per_obj_id_str  \
# 0    inhand_20191112_    20IHPA1A_Test_LHW_01_1.jpg_                     1
# 1    inhand_20191112_    20IHPA1A_Test_LHW_01_2.jpg_                     1
# 2    inhand_20191112_    20IHPA1A_Test_LHW_01_3.jpg_                     1
# 3    inhand_20191112_    20IHPA1A_Test_LHW_01_4.jpg_                     1
# 4    inhand_20191112_    20IHPA1A_Test_LHW_01_5.jpg_                     1
# ..                ...                            ...                   ...
# 496  inhand_20191112_  20IHPA1A_Test_LHW_01_496.jpg_                     1
# 497  inhand_20191112_  20IHPA1A_Test_LHW_01_497.jpg_                     1
# 498  inhand_20191112_  20IHPA1A_Test_LHW_01_498.jpg_                     1
# 499  inhand_20191112_  20IHPA1A_Test_LHW_01_499.jpg_                     1
# 500  inhand_20191112_  20IHPA1A_Test_LHW_01_500.jpg_                     1
#
#              obj_name obj_idx   score     xmin     ymax     xmax     ymin  \
# 0                Null    Null    Null     Null     Null     Null     Null
# 1    grab_bottle_body       8   0.952  434.304  318.384  1151.87   9.2448
# 2    grab_bottle_body       8  0.8984  416.768  304.488  1085.31  5.09616
# 3    grab_bottle_body       8  0.8468  420.224  310.104  1064.96  10.7208
# 4                Null    Null    Null     Null     Null     Null     Null
# ..                ...     ...     ...      ...      ...      ...      ...
# 496              Null    Null    Null     Null     Null     Null     Null
# 497              Null    Null    Null     Null     Null     Null     Null
# 498              Null    Null    Null     Null     Null     Null     Null
# 499              Null    Null    Null     Null     Null     Null     Null
# 500              Null    Null    Null     Null     Null     Null     Null
#
#     width height per_obj_cnt  result_per_obj_id_int
# 0    Null   Null           0                      1
# 1    1280    720           1                      1
# 2    1280    720           1                      1
# 3    1280    720           1                      1
# 4    Null   Null           0                      1
# ..    ...    ...         ...                    ...
# 496  Null   Null           0                      1
# 497  Null   Null           0                      1
# 498  Null   Null           0                      1
# 499  Null   Null           0                      1
# 500  Null   Null           0                      1
#
# [501 rows x 16 columns]

# %%
df.to_csv('C:\\Users\\godof\\Desktop\\original.csv',encoding='utf-8')

# %%
def countLetters(word):
    counter = {}
    for letter in word:
        if letter not in counter:
            counter[letter] = 0
        counter[letter] += 1
    return counter

# %%
t = countLetters(['cap', 'cap', 'cup'])

# %%
k = countLetters(['bottle', 'cap', 'cup'])

# %%
Counter(t) + Counter(k)
# Out:
# Counter({'cap': 3, 'cup': 2, 'bottle': 1})

# %%
orig = {
   'cap': 1,
   'cup': 2,
   'bottle': 3,
}

extra = {
   'cap': 1,
   'cup': 2,
}

# %%
dest = {**orig, **extra}

# %%
dest
# Out:
# {'cap': 1, 'cup': 2, 'bottle': 3}

# %%
from collections import Counter
a = Counter({'cap': 1, 'cup': 2})
b = Counter({'botle': 1, 'cup': 2})

# %%
c = a+b

# %%
c
# Out:
# Counter({'cap': 1, 'cup': 4, 'botle': 1})
